# %% [markdown]
# <a href="https://colab.research.google.com/github/Shashwatpro2021/Gitlearningtutorial/blob/master/Pf_21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# THIS IS TITLE

# %%
print("hello Shashwat")
# Out:
# hello Shashwat

# %%
3+5
# Out:
# 8

# %% [markdown]
# # Public link

# %%
# !wget https://github.com/tpradeep8/tableau-data-visualization/blob/master/titanic%20passenger%20list.csv
# Out:
# --2021-10-15 06:14:15--  https://github.com/tpradeep8/tableau-data-visualization/blob/master/titanic%20passenger%20list.csv
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘titanic passenger list.csv’
#
# titanic passenger l     [   <=>              ] 838.60K  1.59MB/s    in 0.5s
#
# 2021-10-15 06:14:16 (1.59 MB/s) - ‘titanic passenger list.csv’ saved [858731]

# %%
! ls
# Out:
#  sample_data  'titanic passenger list.csv'

# %%
import pandas as pd

# %%
from google.colab import drive

# %%
# !git clone  https://github.com/tpradeep8/tableau-data-visualization/blob/master/titanic%20passenger%20list.csv
# Out:
# Cloning into 'titanic%20passenger%20list.csv'...
# fatal: repository 'https://github.com/tpradeep8/tableau-data-visualization/blob/master/titanic%20passenger%20list.csv/' not found

# %%
# !git clone https://github.com/Shashwatpro2021/Gitlearningtutorial
# Out:
# Cloning into 'Gitlearningtutorial'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 11 (delta 1), reused 7 (delta 0), pack-reused 0
# Unpacking objects: 100% (11/11), done.

# %% [markdown]
# # **This is heading**

# %% [markdown]
# # New Section
#
# ```
# This is formatted as code
# ### print(item)
# ```

# %% [markdown]
# [link text](https://support.google.com/drive/answer/2494822?hl=en&co=GENIE.Platform%3DAndroid)

# %% [markdown]
# 1.   first
# 2.   second

# %% [markdown]
# ghagghj
# *   yri

# %% [markdown]
# ---

# %% [markdown]
# $ ax^2 + bx +c = 0 $
